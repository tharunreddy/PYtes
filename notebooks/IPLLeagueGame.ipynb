# %%
import requests
import arrow

# %%
URL = 'https://2fjfpxrbb3.execute-api.ap-southeast-1.amazonaws.com/production/leagueapi/getleaguemembers?leagueId=ip3NjxML'
userid = 'tarunreddy.bethi@gmail.com'

def get_league_data():
    r = requests.get(URL, headers={'userid': userid})
    return r.json()['data']

league_data = get_league_data()

# %%
members = league_data['leagueMembers']
#Adding a noop to make even number of teams
teams = [member['teamName'] for member in members] + ['NoOP']

# %%
from itertools import combinations, permutations

def schedule(teams):
    """Generates a round robin schedule"""
    teams = teams.copy()
    while True:
        mid = len(teams)//2
        for match in zip(teams[0:mid], teams[mid:]):
            yield match
        last_team = teams.pop()
        teams.insert(1, last_team)

# %%
now = arrow.Arrow.now()

g = schedule(teams)
matches = list(((next(g) for _ in range(500))))

def format(matches):
    for match in matches:
        print("{} vs {}".format(match[0], match[1]))
        
        
for i in range(1, 42):
    time = now.replace(days=i)
    print(time.date())
    format(matches[i*5: i*5 + 5])
    print()
# Out:
# 2018-04-09
# Rocky United vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
#
# 2018-04-10
# Rocky United vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
#
# 2018-04-11
# Rocky United vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
#
# 2018-04-12
# Rocky United vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
#
# 2018-04-13
# Rocky United vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
#
# 2018-04-14
# Rocky United vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
#
# 2018-04-15
# Rocky United vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
#
# 2018-04-16
# Rocky United vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
#
# 2018-04-17
# Rocky United vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
#
# 2018-04-18
# Rocky United vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
#
# 2018-04-19
# Rocky United vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
#
# 2018-04-20
# Rocky United vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
#
# 2018-04-21
# Rocky United vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
#
# 2018-04-22
# Rocky United vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
#
# 2018-04-23
# Rocky United vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
#
# 2018-04-24
# Rocky United vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
#
# 2018-04-25
# Rocky United vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
#
# 2018-04-26
# Rocky United vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
#
# 2018-04-27
# Rocky United vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
#
# 2018-04-28
# Rocky United vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
#
# 2018-04-29
# Rocky United vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
#
# 2018-04-30
# Rocky United vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
#
# 2018-05-01
# Rocky United vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
#
# 2018-05-02
# Rocky United vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
#
# 2018-05-03
# Rocky United vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
#
# 2018-05-04
# Rocky United vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
#
# 2018-05-05
# Rocky United vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
#
# 2018-05-06
# Rocky United vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
#
# 2018-05-07
# Rocky United vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
#
# 2018-05-08
# Rocky United vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
#
# 2018-05-09
# Rocky United vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
#
# 2018-05-10
# Rocky United vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
#
# 2018-05-11
# Rocky United vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
#
# 2018-05-12
# Rocky United vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
#
# 2018-05-13
# Rocky United vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
# BaskinRobins vs RaisedByWolves
#
# 2018-05-14
# Rocky United vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
# Alpine Warriors vs NoOP
#
# 2018-05-15
# Rocky United vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
# TRDY vs MumbaiKarz
#
# 2018-05-16
# Rocky United vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
# Blaugrana vs Warriors
#
# 2018-05-17
# Rocky United vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
# RaisedByWolves vs SujiWuji XI
#
# 2018-05-18
# Rocky United vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
# NoOP vs BaskinRobins
#
# 2018-05-19
# Rocky United vs NoOP
# BaskinRobins vs RaisedByWolves
# SujiWuji XI vs Blaugrana
# Warriors vs TRDY
# MumbaiKarz vs Alpine Warriors
